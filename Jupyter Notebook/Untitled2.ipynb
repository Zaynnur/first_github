# %%
import numpy as np

# %%
np.zeros(3)
# Out:
# array([0., 0., 0.])

# %%
np.ones(3)
# Out:
# array([1., 1., 1.])

# %%
np.empty(6)
# Out:
# array([1.04923491e+165, 5.28802793e+174, 1.42280357e+160, 5.25196357e+170,
#        2.12199579e-314, 3.25060610e-319])

# %%
np.empty(5)
# Out:
# array([2.12199579e-314, 3.83498818e+151, 4.98018171e-321, 3.79442416e-321,
#        0.00000000e+000])

# %%
np.arange(3,31,3)
# Out:
# array([ 3,  6,  9, 12, 15, 18, 21, 24, 27, 30])
