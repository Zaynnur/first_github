# %% [markdown]
# # Numpy Practice Session

# %% [markdown]
# # Import the Library

# %%
import numpy as np

# %%
# food = np.array(["Pakora","Samosa","Raita"])
# food

# %%
# price = np.array([50,50,50])
# price

# %%
# price[0:]

# %%
# food[1]

# %%
np.empty(5)
# Out:
# array([6.23042070e-307, 4.67296746e-307, 1.69121096e-306, 4.22786781e-307,
#        2.12199579e-314])
