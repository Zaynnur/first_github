# %% [markdown]
# # Body mass index (B-M-I)
# - Input Wieght
# - Height
# - BMI (Ask yourself your height)
# - Weight
# - Calculate BMI
# - Print BMI (My name is _____, And my BMI is_____ )

# %%
height = input("What is your Height in m?  ")
# Out:
# What is your Height in m?   1.76

# %%
height = float(height)

# %%
weight = input("Weight is ypur Body Weight in kg?  ")
# Out:
# Weight is ypur Body Weight in kg?   120

# %%
weight = int(weight)

# %%
name = input("What is you name?  ")
# Out:
# What is you name?   l

# %%
BMI = weight/height**2
BMI
# Out:
# 38.739669421487605

# %%
print ("My name is", name,"and my BMI is", BMI)
# Out:
# My name is l and my BMI is 38.739669421487605
